# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaronau667/FinRL-Tutorials/blob/master/FinRL_PortfolioAllocation_NeurIPS_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
sys.path.append("../FinRL-Library")

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
start_date = '2008-01-01'
end_date = '2021-10-31'

# %%
import os
import pandas as pd
from datetime import datetime
import time
import random
import requests

def download_and_save_data(start_date, end_date, ticker_list, data_dir='./data'):

    # Create data storage directory
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    # Generate filename (using date range)
    file_name = f"dow30_data_{start_date}_{end_date}.csv"
    file_path = os.path.join(data_dir, file_name)

    # Check if file already exists
    if os.path.exists(file_path):
        print(f"Loading existing data from {file_path}")
        return pd.read_csv(file_path, index_col=0, parse_dates=True)

    print("Downloading data from Yahoo Finance...")
    # Use modified download function
    def download_with_retry(ticker, start_date, end_date, max_retries=3, delay=2):
        for attempt in range(max_retries):
            try:
                data = YahooDownloader(start_date=start_date,
                                     end_date=end_date,
                                     ticker_list=[ticker]).fetch_data()
                return data
            except Exception as e:
                if attempt < max_retries - 1:
                    sleep_time = delay + random.uniform(0, 1)
                    print(f"Download failed for {ticker}, retrying in {sleep_time:.2f} seconds...")
                    time.sleep(sleep_time)
                else:
                    print(f"Failed to download {ticker} after {max_retries} attempts")
                    raise e

    # Download all stock data
    all_data = []
    for ticker in ticker_list:
        try:
            data = download_with_retry(ticker, start_date, end_date)
            all_data.append(data)
            print(f"Successfully downloaded {ticker}")
        except Exception as e:
            print(f"Error downloading {ticker}: {str(e)}")

    # Merge all data
    if all_data:
        final_df = pd.concat(all_data, axis=0)
        # Save to CSV file
        final_df.to_csv(file_path)
        print(f"Data saved to {file_path}")
        return final_df
    else:
        raise Exception("No data was downloaded successfully")

# Use modified function
df = download_and_save_data(
    start_date=start_date,
    end_date=end_date,
    ticker_list=config_tickers.DOW_30_TICKER
)
# Out:
# Loading existing data from ./data\dow30_data_2008-01-01_2021-10-31.csv
# C:\Users\Aaron_2\AppData\Local\Temp\tmpnp0infbp\ipykernel_31264\1328265345.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.read_csv(file_path, index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#          date      close       high        low       open    volume  tic  day
# 0  2008-01-02  38.898697  39.874212  38.708166  39.698924   8053700  AXP    2
# 1  2008-01-03  38.418545  39.249257  38.258500  39.020621   7753200  AXP    3
# 2  2008-01-04  37.450661  38.098466  37.122948  38.098466   8501400  AXP    4
# 3  2008-01-07  37.618332  38.182300  37.031498  37.747891  14031100  AXP    0
# 4  2008-01-08  36.543743  37.877456  36.398938  37.877456  11721000  AXP    1

# %%
df.shape
# Out:
# (101615, 8)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
import os
import pandas as pd

# 检查处理后的文件是否存在
processed_file_path = f"data/dow30_data_{start_date}_{end_date}_processed.csv"

if os.path.exists(processed_file_path):
    print(f"找到已处理的特征工程文件: {processed_file_path}，直接读取数据...")
    df = pd.read_csv(processed_file_path)
    # 如果需要将字符串日期转换回datetime对象
    if 'date' in df.columns and isinstance(df['date'].iloc[0], str):
        df['date'] = pd.to_datetime(df['date'])
else:
    print(f"未找到已处理的特征工程文件，开始处理数据...")
    # 特征工程处理
    fe = FeatureEngineer(
        use_technical_indicator=True,
        use_turbulence=False,
        user_defined_feature=False)

    df = fe.preprocess_data(df)

    # 创建data目录(如果不存在)
    if not os.path.exists('data'):
        os.makedirs('data')

    # 将处理后的数据保存到data目录
    df.to_csv(processed_file_path, index=False)
    print(f"特征工程处理完成并保存至: {processed_file_path}")
# Out:
# 找到已处理的特征工程文件: data/dow30_data_2008-01-01_2021-10-31_processed.csv，直接读取数据...

# %%
df.shape
# Out:
# (97524, 16)

# %%
df.head()
# Out:
#         date      close       high        low       open      volume   tic  \
# 0 2008-01-02   5.855757   6.018651   5.786934   5.988897  1079178800  AAPL
# 1 2008-01-02  32.223804  32.528065  31.988695  32.223804     7934400  AMGN
# 2 2008-01-02  38.898697  39.874212  38.708166  39.698924     8053700   AXP
# 3 2008-01-02  63.481632  64.375735  63.027248  64.177861     4303000    BA
# 4 2008-01-02  44.507317  45.792818  44.141835  45.723501     6337800   CAT
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0    2   0.0  5.860939  5.853282   100.0 -66.666667  100.0      5.855757
# 1    2   0.0  5.860939  5.853282   100.0 -66.666667  100.0     32.223804
# 2    2   0.0  5.860939  5.853282   100.0 -66.666667  100.0     38.898697
# 3    2   0.0  5.860939  5.853282   100.0 -66.666667  100.0     63.481632
# 4    2   0.0  5.860939  5.853282   100.0 -66.666667  100.0     44.507317
#
#    close_60_sma
# 0      5.855757
# 1     32.223804
# 2     38.898697
# 3     63.481632
# 4     44.507317

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values
  cov_list.append(covs)


df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df.shape
# Out:
# (90468, 18)

# %%
df.head()
# Out:
#         date      close       high        low       open     volume   tic  \
# 0 2008-12-31   2.565124   2.636953   2.564824   2.583758  607541200  AAPL
# 1 2008-12-31  39.934002  40.259007  39.456869  39.491444    6287200  AMGN
# 2 2008-12-31  14.326870  14.481338  13.832574  13.878914    9625600   AXP
# 3 2008-12-31  32.005890  32.290921  31.128298  31.195806    5443100    BA
# 4 2008-12-31  28.895695  29.173849  28.268232  28.268232    6277400   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    2 -0.082003   3.071161   2.436449  42.254748  -80.847374  16.129765
# 1    2  0.149619  40.761999  38.992587  51.060624   51.895824  10.431979
# 2    2 -0.919292  18.322187  12.440030  42.554847  -74.811618  25.744929
# 3    2 -0.279800  32.174386  28.867831  47.440240  157.922155   5.392061
# 4    2  0.639822  29.617321  24.842690  51.205311   98.904648  26.480641
#
#    close_30_sma  close_60_sma  \
# 0      2.729571      2.840867
# 1     39.188100     38.754531
# 2     15.469928     17.309637
# 3     30.327214     32.389915
# 4     26.046880     25.787324
#
#                                             cov_list  \
# 0  [[0.0013489675018974383, 0.0004284139260326614...
# 1  [[0.0013489675018974383, 0.0004284139260326614...
# 2  [[0.0013489675018974383, 0.0004284139260326614...
# 3  [[0.0013489675018974383, 0.0004284139260326614...
# 4  [[0.0013489675018974383, 0.0004284139260326614...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01','2020-07-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)

# %%
train.head()
# Out:
#         date      close       high        low       open     volume   tic  \
# 0 2009-01-02   2.727417   2.736133   2.559414   2.581053  746015200  AAPL
# 0 2009-01-02  40.791454  40.853689  39.933996  40.514854    6547900  AMGN
# 0 2009-01-02  14.929292  15.076036  14.211017  14.342315   10955700   AXP
# 0 2009-01-02  33.941090  34.173615  32.088393  32.103395    7010200    BA
# 0 2009-01-02  30.344679  30.389960  28.921564  29.050939    7117200   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    4 -0.069643   3.057737   2.434395  45.440176  -30.509001   2.140059
# 0    4  0.221590  40.900962  38.958732  52.756850   94.549635   0.814302
# 0    4 -0.817561  18.141769  12.424274  43.957550  -42.018817  16.307082
# 0    4 -0.002009  32.948627  28.452128  50.822025  275.695601  20.530070
# 0    4  0.813118  30.107328  24.822311  53.661240  131.675790  34.780768
#
#    close_30_sma  close_60_sma  \
# 0      2.730413      2.841663
# 0     39.249182     38.838663
# 0     15.468640     17.194816
# 0     30.469478     32.344130
# 0     26.278029     25.787892
#
#                                             cov_list  \
# 0  [[0.0013661491729489213, 0.0004339394692651215...
# 0  [[0.0013661491729489213, 0.0004339394692651215...
# 0  [[0.0013661491729489213, 0.0004339394692651215...
# 0  [[0.0013661491729489213, 0.0004339394692651215...
# 0  [[0.0013661491729489213, 0.0004339394692651215...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step


    """
    metadata = {'render.modes': ['human']}

    def __init__(self,
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,))
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]


    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique())-1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()

            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")

            return self.state, self.reward, self.terminal,{}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions)
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]
        return self.state

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output


    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 28

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
# 首先安装必要的shimmy包
# !pip install 'shimmy>=2.0'

import numpy as np
import gym
import gymnasium
from stable_baselines3.common.vec_env import DummyVecEnv

# 创建一个适配器类，需要继承自gym.Env
class CompatibilityWrapper(gym.Env):
    """兼容性包装器，用于在新版SB3中使用旧版Gym环境"""

    def __init__(self, env):
        """
        参数:
            env: 需要包装的环境
        """
        self.env = env

        # 复制环境的属性
        self.action_space = env.action_space
        self.observation_space = env.observation_space
        self.metadata = getattr(env, 'metadata', {'render_modes': ['human']})
        self.reward_range = getattr(env, 'reward_range', (-float('inf'), float('inf')))

    def reset(self, **kwargs):
        """适配reset方法"""
        # 调用原始环境的reset
        obs = self.env.reset()
        # 返回适配后的结果
        return obs, {}

    def step(self, action):
        """适配step方法"""
        # 调用原始环境的step
        obs, reward, done, info = self.env.step(action)
        # 返回适配后的结果
        if not isinstance(info, dict):
            info = {}
        return obs, reward, done, False, info

    def render(self, mode='human'):
        """适配render方法"""
        return self.env.render(mode)

    def close(self):
        """关闭环境"""
        return self.env.close()

    def seed(self, seed=None):
        """设置随机种子"""
        return self.env.seed(seed) if hasattr(self.env, 'seed') else None

    # 转发所有其他方法和属性到原始环境
    def __getattr__(self, name):
        return getattr(self.env, name)

    @property
    def unwrapped(self):
        return self.env.unwrapped

# 直接从DummyVecEnv创建向量化环境的函数
def direct_dummy_vec_env(env_instance):
    """直接创建DummyVecEnv，跳过_patch_env检查"""
    from stable_baselines3.common.vec_env.base_vec_env import VecEnvIndices
    from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv

    class DirectDummyVecEnv(DummyVecEnv):
        def __init__(self, env_instance):
            self.envs = [env_instance]
            self.env_method_name = None
            self.observation_space = env_instance.observation_space
            self.action_space = env_instance.action_space
            self.num_envs = 1
            self.class_attributes = dir(self.__class__)

            # For backwards compatibility with SB <2.10.0
            if getattr(env_instance, "metadata", None) is not None:
                self.metadata = env_instance.metadata

        def reset(self):
            obs = self.envs[0].reset()
            return np.array([obs])

        def step_async(self, actions):
            self.actions = actions

        def step_wait(self):
            obs, rewards, dones, infos = self.envs[0].step(self.actions[0])
            return np.array([obs]), np.array([rewards]), np.array([dones]), [infos]

        def get_attr(self, attr_name: str, indices: VecEnvIndices = None):
            return [getattr(self.envs[0], attr_name)]

    # 创建并返回直接的DummyVecEnv
    vec_env = DirectDummyVecEnv(env_instance)
    obs = vec_env.reset()
    return vec_env, obs

# 覆盖原始的get_sb_env方法
def get_compatible_env(env_instance):
    """获取与SB3兼容的环境"""
    # 首先尝试直接方法
    try:
        wrapped_env = CompatibilityWrapper(env_instance)
        return direct_dummy_vec_env(wrapped_env)
    except Exception as e1:
        print(f"直接方法失败: {e1}")

        # 尝试其他方法
        try:
            wrapped_env = CompatibilityWrapper(env_instance)
            vec_env = DummyVecEnv([lambda: wrapped_env])
            obs = vec_env.reset()
            return vec_env, obs
        except Exception as e2:
            print(f"标准方法也失败: {e2}")

            # 最后的备选方案
            vec_env = DummyVecEnv([lambda: env_instance])
            obs = np.array([env_instance.reset()])
            return vec_env, obs

# 替换环境的get_sb_env方法
e_train_gym.get_sb_env = lambda: get_compatible_env(e_train_gym)

# 获取环境
env_train, obs_train = e_train_gym.get_sb_env()
print(f"环境类型: {type(env_train)}")
print(f"观察形状: {obs_train.shape}")
# Out:
# 直接方法失败: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1, 2) + inhomogeneous part.
# 标准方法也失败: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# 环境类型: <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# 观察形状: (1, 36, 28)
# ERROR: Invalid requirement: "'shimmy": Expected package name at the start of dependency specifier
#     'shimmy
#     ^
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# 直接方法失败: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1, 2) + inhomogeneous part.
# 标准方法也失败: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cuda device
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
trained_a2c = agent.train_model(model=model_a2c,
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 306       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.99e+08  |
# |    reward             | 1674928.5 |
# |    std                | 0.997     |
# |    value_loss         | 2.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 340       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.61e+08  |
# |    reward             | 2194662.5 |
# |    std                | 0.996     |
# |    value_loss         | 5.12e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 300       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 4e+08     |
# |    reward             | 3393356.5 |
# |    std                | 0.996     |
# |    value_loss         | 1.27e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 400       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 4.69e+08  |
# |    reward             | 4215288.0 |
# |    std                | 0.995     |
# |    value_loss         | 1.79e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 357       |
# |    iterations         | 500       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 6.67e+08  |
# |    reward             | 5769877.0 |
# |    std                | 0.995     |
# |    value_loss         | 3.73e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6458855.265541655
# Sharpe:  0.9752229978839396
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 600       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.23e+08  |
# |    reward             | 1075119.8 |
# |    std                | 0.993     |
# |    value_loss         | 1.15e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 700       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.96e+08  |
# |    reward             | 1658532.4 |
# |    std                | 0.994     |
# |    value_loss         | 3.02e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 346       |
# |    iterations         | 800       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 2.93e+08  |
# |    reward             | 2405883.2 |
# |    std                | 0.994     |
# |    value_loss         | 6.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 346       |
# |    iterations         | 900       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.56e+08  |
# |    reward             | 3328418.0 |
# |    std                | 0.993     |
# |    value_loss         | 1.17e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 349       |
# |    iterations         | 1000      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 4.6e+08   |
# |    reward             | 4052008.2 |
# |    std                | 0.993     |
# |    value_loss         | 1.81e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 349       |
# |    iterations         | 1100      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 6.4e+08   |
# |    reward             | 5511461.0 |
# |    std                | 0.993     |
# |    value_loss         | 3.42e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5704275.681892187
# Sharpe:  0.9265281914625993
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 346       |
# |    iterations         | 1200      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.52e+08  |
# |    reward             | 1308135.2 |
# |    std                | 0.993     |
# |    value_loss         | 1.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 1300      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 2.11e+08  |
# |    reward             | 1655153.2 |
# |    std                | 0.993     |
# |    value_loss         | 3.03e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 1400      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 3e+08     |
# |    reward             | 2626545.5 |
# |    std                | 0.993     |
# |    value_loss         | 7.18e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 341       |
# |    iterations         | 1500      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 3.77e+08  |
# |    reward             | 3297971.8 |
# |    std                | 0.993     |
# |    value_loss         | 1.1e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 341       |
# |    iterations         | 1600      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 4.96e+08  |
# |    reward             | 4395965.0 |
# |    std                | 0.992     |
# |    value_loss         | 2e+14     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 342       |
# |    iterations         | 1700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 6.27e+08  |
# |    reward             | 5838737.5 |
# |    std                | 0.992     |
# |    value_loss         | 3.43e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5889894.214597682
# Sharpe:  0.9392743696335702
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 341       |
# |    iterations         | 1800      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 1.71e+08  |
# |    reward             | 1492557.6 |
# |    std                | 0.991     |
# |    value_loss         | 2.29e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 340       |
# |    iterations         | 1900      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.15e+08  |
# |    reward             | 1905638.4 |
# |    std                | 0.991     |
# |    value_loss         | 3.89e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 341       |
# |    iterations         | 2000      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 3.07e+08  |
# |    reward             | 2692767.8 |
# |    std                | 0.99      |
# |    value_loss         | 7.48e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 2100      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 3.49e+08  |
# |    reward             | 3261750.0 |
# |    std                | 0.989     |
# |    value_loss         | 1.11e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 2200      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 5.8e+08   |
# |    reward             | 4563409.0 |
# |    std                | 0.988     |
# |    value_loss         | 2.48e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 2300      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 5.35e+08  |
# |    reward             | 4397736.5 |
# |    std                | 0.988     |
# |    value_loss         | 2.71e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5666960.777037312
# Sharpe:  0.9149621062769435
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 2400      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1452530.0 |
# |    std                | 0.988     |
# |    value_loss         | 2.12e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 339       |
# |    iterations         | 2500      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 2.41e+08  |
# |    reward             | 2027137.4 |
# |    std                | 0.988     |
# |    value_loss         | 4.23e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 340       |
# |    iterations         | 2600      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 3.49e+08  |
# |    reward             | 2966363.0 |
# |    std                | 0.988     |
# |    value_loss         | 9.26e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 342       |
# |    iterations         | 2700      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 3.93e+08  |
# |    reward             | 3562391.8 |
# |    std                | 0.987     |
# |    value_loss         | 1.37e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 2800      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 5.78e+08  |
# |    reward             | 5078379.0 |
# |    std                | 0.987     |
# |    value_loss         | 2.68e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5546680.770902898
# Sharpe:  0.9024069905653089
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 2900      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 1.06e+08  |
# |    reward             | 854750.94 |
# |    std                | 0.987     |
# |    value_loss         | 8.64e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 345       |
# |    iterations         | 3000      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 2.03e+08  |
# |    reward             | 1688937.9 |
# |    std                | 0.986     |
# |    value_loss         | 3.01e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 3100      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 2.46e+08  |
# |    reward             | 2169541.5 |
# |    std                | 0.986     |
# |    value_loss         | 4.93e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 3200      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 3.56e+08  |
# |    reward             | 3261542.2 |
# |    std                | 0.985     |
# |    value_loss         | 1.09e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 342       |
# |    iterations         | 3300      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 4.44e+08  |
# |    reward             | 3950305.5 |
# |    std                | 0.985     |
# |    value_loss         | 1.65e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 3400      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 6.13e+08  |
# |    reward             | 5225217.5 |
# |    std                | 0.985     |
# |    value_loss         | 2.85e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6069538.239890206
# Sharpe:  0.9475028284688572
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 342       |
# |    iterations         | 3500      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.31e+08  |
# |    reward             | 1153158.6 |
# |    std                | 0.984     |
# |    value_loss         | 1.33e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 3600      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 2.02e+08  |
# |    reward             | 1770522.6 |
# |    std                | 0.984     |
# |    value_loss         | 3.27e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 3700      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.94e+08  |
# |    reward             | 2538046.8 |
# |    std                | 0.984     |
# |    value_loss         | 6.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 3800      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 3.94e+08  |
# |    reward             | 3481385.2 |
# |    std                | 0.984     |
# |    value_loss         | 1.23e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 3900      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 4.89e+08  |
# |    reward             | 4370361.5 |
# |    std                | 0.984     |
# |    value_loss         | 2.04e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 4000      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 7.03e+08  |
# |    reward             | 6320109.0 |
# |    std                | 0.983     |
# |    value_loss         | 4.13e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6529407.448864545
# Sharpe:  0.9835101053279612
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 4100      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 1.67e+08  |
# |    reward             | 1447847.2 |
# |    std                | 0.982     |
# |    value_loss         | 2.14e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 4200      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 1.93e+08  |
# |    reward             | 1797708.5 |
# |    std                | 0.982     |
# |    value_loss         | 3.36e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 343       |
# |    iterations         | 4300      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 3.23e+08  |
# |    reward             | 2765249.5 |
# |    std                | 0.981     |
# |    value_loss         | 8.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 4400      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 3.92e+08  |
# |    reward             | 3437173.0 |
# |    std                | 0.981     |
# |    value_loss         | 1.31e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 344       |
# |    iterations         | 4500      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 5.78e+08  |
# |    reward             | 5103380.5 |
# |    std                | 0.98      |
# |    value_loss         | 2.74e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 345       |
# |    iterations         | 4600      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 7.55e+08  |
# |    reward             | 6406349.0 |
# |    std                | 0.98      |
# |    value_loss         | 4.45e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6296581.086691162
# Sharpe:  0.9689001530411254
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 346       |
# |    iterations         | 4700      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.76e+08  |
# |    reward             | 1463687.6 |
# |    std                | 0.98      |
# |    value_loss         | 2.13e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 4800      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 2.27e+08  |
# |    reward             | 1970010.6 |
# |    std                | 0.979     |
# |    value_loss         | 4.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 348       |
# |    iterations         | 4900      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 3.4e+08   |
# |    reward             | 2918887.2 |
# |    std                | 0.979     |
# |    value_loss         | 8.87e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 349       |
# |    iterations         | 5000      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 3.87e+08  |
# |    reward             | 3489509.8 |
# |    std                | 0.978     |
# |    value_loss         | 1.33e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 349       |
# |    iterations         | 5100      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 5.99e+08  |
# |    reward             | 5073779.0 |
# |    std                | 0.978     |
# |    value_loss         | 2.6e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 5200      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 7.05e+08  |
# |    reward             | 6025509.0 |
# |    std                | 0.978     |
# |    value_loss         | 3.86e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6459233.737282105
# Sharpe:  0.9871408278680425
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 5300      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.93e+08  |
# |    reward             | 1560360.6 |
# |    std                | 0.977     |
# |    value_loss         | 2.54e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 5400      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.37e+08  |
# |    reward             | 1970491.1 |
# |    std                | 0.977     |
# |    value_loss         | 4.37e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 5500      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 3.09e+08  |
# |    reward             | 2928894.8 |
# |    std                | 0.977     |
# |    value_loss         | 8.33e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 5600      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 4.18e+08  |
# |    reward             | 3406827.0 |
# |    std                | 0.977     |
# |    value_loss         | 1.24e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 5700      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 5.65e+08  |
# |    reward             | 4911565.0 |
# |    std                | 0.976     |
# |    value_loss         | 2.83e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5763064.958218482
# Sharpe:  0.9340990710608116
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 5800      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 1.04e+08  |
# |    reward             | 968705.44 |
# |    std                | 0.975     |
# |    value_loss         | 9.37e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 5900      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1655937.2 |
# |    std                | 0.975     |
# |    value_loss         | 2.87e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6000      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 2.41e+08  |
# |    reward             | 2213952.5 |
# |    std                | 0.975     |
# |    value_loss         | 5.22e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6100      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 3.75e+08  |
# |    reward             | 3222839.2 |
# |    std                | 0.975     |
# |    value_loss         | 1.14e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6200      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 4.78e+08  |
# |    reward             | 3928820.0 |
# |    std                | 0.974     |
# |    value_loss         | 1.69e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6300      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 6.27e+08  |
# |    reward             | 5330834.5 |
# |    std                | 0.974     |
# |    value_loss         | 2.92e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5761633.640559818
# Sharpe:  0.9338209540093173
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6400      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1259517.0 |
# |    std                | 0.974     |
# |    value_loss         | 1.57e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6500      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6499      |
# |    policy_loss        | 1.82e+08  |
# |    reward             | 1525810.0 |
# |    std                | 0.973     |
# |    value_loss         | 2.68e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6600      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.67e+08  |
# |    reward             | 2364494.0 |
# |    std                | 0.974     |
# |    value_loss         | 5.84e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6700      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6699      |
# |    policy_loss        | 3.31e+08  |
# |    reward             | 2913077.8 |
# |    std                | 0.973     |
# |    value_loss         | 9.2e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6800      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6799      |
# |    policy_loss        | 4.74e+08  |
# |    reward             | 4046245.5 |
# |    std                | 0.973     |
# |    value_loss         | 1.75e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6900      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6899      |
# |    policy_loss        | 5.99e+08  |
# |    reward             | 5395878.5 |
# |    std                | 0.973     |
# |    value_loss         | 3.02e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5552666.455259735
# Sharpe:  0.9183279531492833
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 7000      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6999      |
# |    policy_loss        | 1.49e+08  |
# |    reward             | 1342955.1 |
# |    std                | 0.973     |
# |    value_loss         | 1.78e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 7100      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7099      |
# |    policy_loss        | 2.24e+08  |
# |    reward             | 1840406.0 |
# |    std                | 0.974     |
# |    value_loss         | 3.54e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 7200      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7199      |
# |    policy_loss        | 2.89e+08  |
# |    reward             | 2642039.2 |
# |    std                | 0.973     |
# |    value_loss         | 7.19e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 7300      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7299      |
# |    policy_loss        | 3.4e+08   |
# |    reward             | 3173499.5 |
# |    std                | 0.973     |
# |    value_loss         | 1.02e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 7400      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 5.61e+08  |
# |    reward             | 5325948.5 |
# |    std                | 0.972     |
# |    value_loss         | 3e+14     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 7500      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7499      |
# |    policy_loss        | 7.72e+08  |
# |    reward             | 6555767.5 |
# |    std                | 0.972     |
# |    value_loss         | 4.75e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6228175.778222992
# Sharpe:  0.9758079973591685
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 7600      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7599      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1423002.5 |
# |    std                | 0.971     |
# |    value_loss         | 2.08e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 7700      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 2.61e+08  |
# |    reward             | 1971992.0 |
# |    std                | 0.971     |
# |    value_loss         | 4.12e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 7800      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 3.55e+08  |
# |    reward             | 3035951.0 |
# |    std                | 0.969     |
# |    value_loss         | 9.77e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 7900      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 4.01e+08  |
# |    reward             | 3743704.5 |
# |    std                | 0.97      |
# |    value_loss         | 1.38e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8000      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 5.73e+08  |
# |    reward             | 4998635.5 |
# |    std                | 0.97      |
# |    value_loss         | 2.7e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8100      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 7.07e+08  |
# |    reward             | 6348647.5 |
# |    std                | 0.969     |
# |    value_loss         | 4.47e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6415419.2973127775
# Sharpe:  0.9857771725289829
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8200      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1628021.6 |
# |    std                | 0.969     |
# |    value_loss         | 2.8e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8300      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 2.43e+08  |
# |    reward             | 2126969.0 |
# |    std                | 0.968     |
# |    value_loss         | 4.79e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8400      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 3.67e+08  |
# |    reward             | 3216166.5 |
# |    std                | 0.968     |
# |    value_loss         | 1.19e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8500      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 4.35e+08  |
# |    reward             | 3807357.8 |
# |    std                | 0.967     |
# |    value_loss         | 1.49e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8600      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 5.91e+08  |
# |    reward             | 5536754.0 |
# |    std                | 0.967     |
# |    value_loss         | 3.12e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6235163.596988922
# Sharpe:  0.9771025997164545
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 8700      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8699      |
# |    policy_loss        | 1.14e+08  |
# |    reward             | 1072011.9 |
# |    std                | 0.966     |
# |    value_loss         | 1.11e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 8800      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 2.02e+08  |
# |    reward             | 1658937.8 |
# |    std                | 0.966     |
# |    value_loss         | 3e+13     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 8900      |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 2.78e+08  |
# |    reward             | 2397356.0 |
# |    std                | 0.966     |
# |    value_loss         | 6.15e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9000      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 3.76e+08  |
# |    reward             | 3367100.5 |
# |    std                | 0.965     |
# |    value_loss         | 1.18e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9100      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 4.7e+08   |
# |    reward             | 4066521.5 |
# |    std                | 0.964     |
# |    value_loss         | 1.77e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9200      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 5.61e+08  |
# |    reward             | 5510833.0 |
# |    std                | 0.964     |
# |    value_loss         | 3.35e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6330936.7768268455
# Sharpe:  0.9846962837104233
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9300      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 1.44e+08  |
# |    reward             | 1285935.5 |
# |    std                | 0.963     |
# |    value_loss         | 1.79e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9400      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 1.9e+08   |
# |    reward             | 1834784.1 |
# |    std                | 0.963     |
# |    value_loss         | 3.24e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9500      |
# |    time_elapsed       | 134       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 3.1e+08   |
# |    reward             | 2846288.2 |
# |    std                | 0.963     |
# |    value_loss         | 8.31e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9600      |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 4.25e+08  |
# |    reward             | 3564018.8 |
# |    std                | 0.963     |
# |    value_loss         | 1.34e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9700      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 5.39e+08  |
# |    reward             | 4952931.0 |
# |    std                | 0.962     |
# |    value_loss         | 2.58e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9800      |
# |    time_elapsed       | 138       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 8.2e+08   |
# |    reward             | 6667261.5 |
# |    std                | 0.962     |
# |    value_loss         | 4.59e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6713452.522424511
# Sharpe:  1.0159026435737533
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 9900      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.73e+08  |
# |    reward             | 1471648.8 |
# |    std                | 0.962     |
# |    value_loss         | 2.27e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 10000     |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 2.24e+08  |
# |    reward             | 2005173.8 |
# |    std                | 0.961     |
# |    value_loss         | 4.21e+13  |
# -------------------------------------

# %%
trained_a2c.save('/content/trained_models/trained_a2c.zip')
# Out:
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path '\content\trained_models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cuda device
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 473       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 4187343.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6219425.100762817
# Sharpe:  0.9616967469942584
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 443           |
# |    iterations           | 2             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.2776582e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 9.91e+14      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -5.19e-07     |
# |    reward               | 2606065.0     |
# |    std                  | 1             |
# |    value_loss           | 1.83e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6175312.918335893
# Sharpe:  0.9526776568216707
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 453           |
# |    iterations           | 3             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.1903467e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.59e+15      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -3.53e-07     |
# |    reward               | 1352533.9     |
# |    std                  | 1             |
# |    value_loss           | 3.78e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 4             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.2340024e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.48e+15      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -3.59e-07     |
# |    reward               | 5239775.0     |
# |    std                  | 1             |
# |    value_loss           | 4.56e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6045852.748686916
# Sharpe:  0.9525060607005247
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 1.231092e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -39.7        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.38e+15     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -4.3e-07     |
# |    reward               | 3451219.2    |
# |    std                  | 1            |
# |    value_loss           | 2.79e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6179239.257703596
# Sharpe:  0.9640788538567702
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 6             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.1466909e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.32e+15      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -5.16e-07     |
# |    reward               | 1741857.0     |
# |    std                  | 1             |
# |    value_loss           | 2.98e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 460           |
# |    iterations           | 7             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.2660166e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.74e+15      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -3.89e-07     |
# |    reward               | 6474254.0     |
# |    std                  | 1             |
# |    value_loss           | 4.37e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6310641.019543045
# Sharpe:  0.9695266874744314
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 460           |
# |    iterations           | 8             |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.3184035e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.92e+15      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -3.56e-07     |
# |    reward               | 3571227.8     |
# |    std                  | 1             |
# |    value_loss           | 4.17e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5894016.815154166
# Sharpe:  0.9347317004751834
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 9             |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.2660166e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 9.12e+14      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -6.19e-07     |
# |    reward               | 2447662.2     |
# |    std                  | 1             |
# |    value_loss           | 1.97e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6494890.216888405
# Sharpe:  0.9845514198218505
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 459            |
# |    iterations           | 10             |
# |    time_elapsed         | 44             |
# |    total_timesteps      | 20480          |
# | train/                  |                |
# |    approx_kl            | 1.21071935e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.65e+15       |
# |    n_updates            | 90             |
# |    policy_gradient_loss | -3.21e-07      |
# |    reward               | 1386576.9      |
# |    std                  | 1              |
# |    value_loss           | 3.7e+15        |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 11            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.2660166e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.73e+15      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -3.37e-07     |
# |    reward               | 5215869.0     |
# |    std                  | 1             |
# |    value_loss           | 5.29e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6111846.834757875
# Sharpe:  0.9566461798146715
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 12            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.1990778e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.29e+15      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -4.25e-07     |
# |    reward               | 3130618.5     |
# |    std                  | 1             |
# |    value_loss           | 2.3e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6157329.524329407
# Sharpe:  0.9581534601682946
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 13           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 1.231092e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -39.7        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.49e+15     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -3.86e-07    |
# |    reward               | 1747337.5    |
# |    std                  | 1            |
# |    value_loss           | 3.33e+15     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 14            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.1961674e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.16e+15      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -4.45e-07     |
# |    reward               | 6319513.5     |
# |    std                  | 1             |
# |    value_loss           | 4.5e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6785200.6176125705
# Sharpe:  0.9999000253962167
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 15            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.1816155e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.99e+15      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -4.27e-07     |
# |    reward               | 3235860.2     |
# |    std                  | 1             |
# |    value_loss           | 3.88e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6416384.954942603
# Sharpe:  0.9771469027485096
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 16            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.3038516e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.42e+15      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -4.32e-07     |
# |    reward               | 2094530.9     |
# |    std                  | 1             |
# |    value_loss           | 2.79e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6347098.3881653175
# Sharpe:  0.97228993953826
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 17            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 1.2572855e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.16e+15      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -4.22e-07     |
# |    reward               | 1045297.9     |
# |    std                  | 1             |
# |    value_loss           | 4.39e+15      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 460            |
# |    iterations           | 18             |
# |    time_elapsed         | 80             |
# |    total_timesteps      | 36864          |
# | train/                  |                |
# |    approx_kl            | 1.19325705e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.64e+15       |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -3.08e-07      |
# |    reward               | 4413189.0      |
# |    std                  | 1              |
# |    value_loss           | 5.16e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6024247.059321897
# Sharpe:  0.9497850059323263
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 460           |
# |    iterations           | 19            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 1.2252713e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.06e+15      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -4.42e-07     |
# |    reward               | 2766445.8     |
# |    std                  | 1             |
# |    value_loss           | 2.03e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5799000.883824129
# Sharpe:  0.9260902659561573
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 20            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.2456439e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.91e+15      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -3.52e-07     |
# |    reward               | 1517280.9     |
# |    std                  | 1             |
# |    value_loss           | 3.67e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 21            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.1612428e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.26e+15      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -3.38e-07     |
# |    reward               | 5107693.0     |
# |    std                  | 1             |
# |    value_loss           | 4.38e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6304471.350985842
# Sharpe:  0.969621941155019
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 22           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 1.231092e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -39.7        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.63e+15     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -3.69e-07    |
# |    reward               | 3492345.8    |
# |    std                  | 1            |
# |    value_loss           | 3.18e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6175205.96704654
# Sharpe:  0.9603487587011981
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 23            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.2601959e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.44e+15      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -4.93e-07     |
# |    reward               | 2057483.2     |
# |    std                  | 1             |
# |    value_loss           | 2.95e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 24            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.2369128e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.88e+15      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -3.79e-07     |
# |    reward               | 6100258.0     |
# |    std                  | 1             |
# |    value_loss           | 4.41e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6341295.803293516
# Sharpe:  0.9735996983135576
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 25            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 1.2863893e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.72e+15      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -2.64e-07     |
# |    reward               | 3888059.2     |
# |    std                  | 1             |
# |    value_loss           | 5.03e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5752138.296550968
# Sharpe:  0.9264307339691742
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 26           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 1.231092e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -39.7        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 8.19e+14     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -4.93e-07    |
# |    reward               | 2382306.2    |
# |    std                  | 1            |
# |    value_loss           | 1.76e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5537500.279096502
# Sharpe:  0.9082273093165174
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 27            |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.1787051e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.66e+15      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -4.59e-07     |
# |    reward               | 1550337.0     |
# |    std                  | 1             |
# |    value_loss           | 3.54e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 28            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.3096724e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.02e+15      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -3.11e-07     |
# |    reward               | 5037286.5     |
# |    std                  | 1             |
# |    value_loss           | 3.97e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5874695.021571491
# Sharpe:  0.9328505355530976
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 29            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 1.0972144e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.3e+15       |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -5.3e-07      |
# |    reward               | 3124879.5     |
# |    std                  | 1             |
# |    value_loss           | 2.6e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5919883.272227144
# Sharpe:  0.940403962456555
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 30            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.2601959e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.33e+15      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -3.78e-07     |
# |    reward               | 1565798.8     |
# |    std                  | 1             |
# |    value_loss           | 2.91e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 31            |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.2048986e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.11e+15      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -3.09e-07     |
# |    reward               | 6079527.5     |
# |    std                  | 1             |
# |    value_loss           | 3.97e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5975940.269069777
# Sharpe:  0.9365021237317036
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 32            |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 1.3562385e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.78e+15      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -3.38e-07     |
# |    reward               | 3502477.5     |
# |    std                  | 1             |
# |    value_loss           | 3.81e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6055887.267062561
# Sharpe:  0.9526871375412437
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 33            |
# |    time_elapsed         | 147           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.1263182e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.01e+15      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -5.6e-07      |
# |    reward               | 2228506.0     |
# |    std                  | 1             |
# |    value_loss           | 1.95e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6302441.898750847
# Sharpe:  0.9655492999098886
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 34           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 1.231092e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -39.7        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.79e+15     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -4.09e-07    |
# |    reward               | 1296418.4    |
# |    std                  | 1            |
# |    value_loss           | 3.81e+15     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 35            |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.2252713e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.57e+15      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -3.39e-07     |
# |    reward               | 4779531.5     |
# |    std                  | 1             |
# |    value_loss           | 4.83e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5835876.778823767
# Sharpe:  0.9315900294698044
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 36            |
# |    time_elapsed         | 160           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.2427336e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.02e+15      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -4.91e-07     |
# |    reward               | 3026480.5     |
# |    std                  | 1             |
# |    value_loss           | 2.17e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6293024.975504446
# Sharpe:  0.9649144174461395
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 37            |
# |    time_elapsed         | 165           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 1.1437805e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.69e+15      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -4.61e-07     |
# |    reward               | 1711736.8     |
# |    std                  | 1             |
# |    value_loss           | 3.32e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 458           |
# |    iterations           | 38            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 1.1437805e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.99e+15      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -4.54e-07     |
# |    reward               | 5710899.0     |
# |    std                  | 1             |
# |    value_loss           | 4.61e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6238948.126681071
# Sharpe:  0.9600387715119405
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 457           |
# |    iterations           | 39            |
# |    time_elapsed         | 174           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.2340024e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.81e+15      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -3.09e-07     |
# |    reward               | 3305432.0     |
# |    std                  | 1             |
# |    value_loss           | 3.61e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5491967.233939294
# Sharpe:  0.9047614761262465
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 457           |
# |    iterations           | 40            |
# |    time_elapsed         | 178           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.2194505e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.23e+15      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -4.79e-07     |
# |    reward               | 1889043.6     |
# |    std                  | 1             |
# |    value_loss           | 2.59e+15      |
# -------------------------------------------

# %%
trained_ppo.save('/content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:5991905.415366534
# Sharpe:  0.9516814560416598
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 171       |
# |    time_elapsed    | 67        |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -1.32e+08 |
# |    critic_loss     | 2.12e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11471     |
# |    reward          | 5773161.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 169       |
# |    time_elapsed    | 136       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -1.98e+08 |
# |    critic_loss     | 5.87e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23043     |
# |    reward          | 5773161.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 168       |
# |    time_elapsed    | 206       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -2.53e+08 |
# |    critic_loss     | 8.53e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34615     |
# |    reward          | 5773161.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 167       |
# |    time_elapsed    | 275       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -2.86e+08 |
# |    critic_loss     | 9.35e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46187     |
# |    reward          | 5773161.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5773161.546049173
# Sharpe:  0.938510014499584
# =================================

# %%
trained_ddpg.save('/content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device

# %%
trained_sac = agent.train_model(model=model_sac,
                             tb_log_name='sac',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:5249644.459073269
# Sharpe:  0.8664866862981275
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5239085.284049942
# Sharpe:  0.8609730122553975
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5239115.384031524
# Sharpe:  0.8609780588999454
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5239257.278383997
# Sharpe:  0.8609900444457859
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 115       |
# |    time_elapsed    | 100       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -1.3e+08  |
# |    critic_loss     | 1.62e+12  |
# |    ent_coef        | 3.27      |
# |    ent_coef_loss   | -203      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 11471     |
# |    reward          | 5239257.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5239296.366233305
# Sharpe:  0.8609964721456198
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5239489.77749508
# Sharpe:  0.8610235641184711
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5239468.053279559
# Sharpe:  0.8610760347539627
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5240261.115049924
# Sharpe:  0.8611760397972851
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 112       |
# |    time_elapsed    | 205       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -2.02e+08 |
# |    critic_loss     | 4.07e+12  |
# |    ent_coef        | 87.7      |
# |    ent_coef_loss   | -392      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 23043     |
# |    reward          | 5240261.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5240366.113390021
# Sharpe:  0.861257540311786
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5252158.481455641
# Sharpe:  0.8624781874697253
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5235028.011350798
# Sharpe:  0.8617198632151121
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5322114.306714543
# Sharpe:  0.869581815385247
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 112       |
# |    time_elapsed    | 308       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -2.38e+08 |
# |    critic_loss     | 1.17e+13  |
# |    ent_coef        | 1.6e+03   |
# |    ent_coef_loss   | -74       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 34615     |
# |    reward          | 5322114.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5313846.433172979
# Sharpe:  0.8700201296409951
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5365156.898388962
# Sharpe:  0.8751410640510666
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5263440.5779910805
# Sharpe:  0.8667339548041886
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5395584.750697861
# Sharpe:  0.8771179534408756
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 112       |
# |    time_elapsed    | 411       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -2.6e+08  |
# |    critic_loss     | 1.11e+13  |
# |    ent_coef        | 2.42e+03  |
# |    ent_coef_loss   | -4.97     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46187     |
# |    reward          | 5395585.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5240312.360293071
# Sharpe:  0.8644684824590775
# =================================

# %%
trained_sac.save('/content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:5675416.513683438
# Sharpe:  0.9077117517411494
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 183       |
# |    time_elapsed    | 62        |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -7.72e+07 |
# |    critic_loss     | 8.87e+11  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11471     |
# |    reward          | 5739348.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 183       |
# |    time_elapsed    | 126       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -1.29e+08 |
# |    critic_loss     | 5.61e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23043     |
# |    reward          | 5739348.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5739348.733838461
# Sharpe:  0.9029069523094823
# =================================

# %%
trained_td3.save('/content/trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df,'2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
trade.shape
# Out:
# (9436, 18)

# %%
import os
import pandas as pd
from stable_baselines3 import A2C
from finrl.agents.stablebaselines3.models import DRLAgent

def load_model_and_predict(model_path, environment):
    """
    从本地目录加载训练好的模型并在已有环境上进行预测

    参数:
    model_path (str): 模型文件的路径，例如 './trained_models/trained_a2c.zip'
    environment: 已经初始化的交易环境对象

    返回:
    tuple: (df_daily_return, df_actions) 每日回报数据和动作数据
    """
    # 检查模型文件是否存在
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"模型文件不存在: {model_path}")

    print(f"从本地加载模型: {model_path}")

    # 加载模型并进行预测
    try:
        # 创建DRLAgent实例
        agent = DRLAgent(env=environment)

        # 加载已训练的模型
        loaded_model = agent.get_model("a2c")  # 创建一个新的模型实例
        loaded_model.load(model_path)  # 加载保存的权重

        print("模型加载成功，开始预测...")
        df_daily_return, df_actions = DRLAgent.DRL_prediction(
            model=loaded_model,
            environment=environment
        )

        # 保存结果到本地
        os.makedirs("./results", exist_ok=True)
        df_daily_return.to_csv("./results/df_daily_return.csv", index=False)
        df_actions.to_csv("./results/df_actions.csv", index=False)

        print(f"预测结果已保存到 ./results/ 目录")

        return df_daily_return, df_actions

    except Exception as e:
        print(f"预测过程中出错: {str(e)}")
        raise

# %%
# 假设e_trade_gym已经在你的环境中初始化好了
model_path = "/content/trained_models/trained_a2c.zip"
df_daily_return, df_actions = load_model_and_predict(model_path, e_trade_gym)
# Out:
# 从本地加载模型: /content/trained_models/trained_a2c.zip
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# d:\0Awork\Envs\FinRL311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# 模型加载成功，开始预测...
# =================================
# begin_total_asset:1000000
# end_total_asset:1423316.4174811982
# Sharpe:  2.0030124827416356
# =================================
# hit end!
# 预测结果已保存到 ./results/ 目录

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
#       2                         environment = e_trade_gym)
#
# NameError: name 'trained_a2c' is not defined

# %%
df_daily_return.head()
# Out:
#         date  daily_return
# 0 2020-07-01      0.000000
# 1 2020-07-02      0.004603
# 2 2020-07-06      0.015921
# 3 2020-07-07     -0.013775
# 4 2020-07-08      0.005647

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.035654  0.035654  0.035654  0.035693  0.035654  0.035654
# 2020-07-06  0.035639  0.035639  0.035639  0.035691  0.035639  0.035639
# 2020-07-07  0.035638  0.035638  0.035638  0.035638  0.035638  0.035638
# 2020-07-08  0.035691  0.035642  0.035642  0.035642  0.035642  0.035642
#
#                 CSCO       CVX       DIS        GS  ...       MMM       MRK  \
# date                                                ...
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  ...  0.035714  0.035714
# 2020-07-02  0.035654  0.035654  0.036073  0.035654  ...  0.035654  0.035654
# 2020-07-06  0.035639  0.035639  0.036155  0.035639  ...  0.035639  0.035639
# 2020-07-07  0.035638  0.035638  0.035969  0.035638  ...  0.035638  0.035638
# 2020-07-08  0.035642  0.035642  0.036033  0.035642  ...  0.035642  0.035642
#
#                 MSFT       NKE        PG       TRV       UNH        VZ  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.035654  0.035654  0.035692  0.035761  0.035938  0.035938
# 2020-07-06  0.035639  0.035639  0.035694  0.035764  0.035930  0.035998
# 2020-07-07  0.035638  0.035638  0.035638  0.036012  0.035792  0.036219
# 2020-07-08  0.035642  0.035642  0.035716  0.035783  0.035667  0.036058
#
#                  WBA       WMT
# date
# 2020-07-01  0.035714  0.035714
# 2020-07-02  0.035654  0.035654
# 2020-07-06  0.035639  0.035639
# 2020-07-07  0.035638  0.035638
# 2020-07-08  0.035642  0.035642
#
# [5 rows x 28 columns]

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats
perf_stats_all = perf_func( returns=DRL_strat,
                              factor_returns=DRL_strat,
                                positions=None, transactions=None, turnover_denom="AGB")

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.302072
# Cumulative returns     0.423316
# Annual volatility      0.136484
# Sharpe ratio           2.003012
# Calmar ratio           3.610611
# Stability              0.919300
# Max drawdown          -0.083662
# Omega ratio            1.396520
# Sortino ratio          3.056092
# Skew                  -0.142189
# Kurtosis               1.369830
# Tail ratio             1.110148
# Daily value at risk   -0.016111
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI",
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.279047
# Cumulative returns     0.388402
# Annual volatility      0.139129
# Sharpe ratio           1.844560
# Calmar ratio           3.124551
# Stability              0.918675
# Max drawdown          -0.089308
# Omega ratio            1.358960
# Sortino ratio          2.734872
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016510
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return.loc[0,'date'], end='2021-11-01'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (337, 8)
# d:\0Awork\Envs\FinRL311\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30.207%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>30.207%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>42.332%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.648%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.61</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.366%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.06</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.14</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.37</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.611%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.97</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.37</td>
#       <td>2020-09-02</td>
#       <td>2020-10-28</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.40</td>
#       <td>2021-08-16</td>
#       <td>2021-09-21</td>
#       <td>2021-10-20</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.90</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-07-02</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.59</td>
#       <td>2021-01-21</td>
#       <td>2021-01-29</td>
#       <td>2021-02-05</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.20</td>
#       <td>2021-02-24</td>
#       <td>2021-03-04</td>
#       <td>2021-03-10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# d:\0Awork\Envs\FinRL311\Lib\site-packages\pyfolio\plotting.py:1407: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Daily", "Weekly", "Monthly"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Covid</th>
#       <td>0.11%</td>
#       <td>-3.27%</td>
#       <td>3.80%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %pip install PyPortfolioOpt
# Out:
# Looking in indexes: https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple
# Requirement already satisfied: PyPortfolioOpt in d:\0awork\envs\finrl311\lib\site-packages (1.5.6)
# Requirement already satisfied: cvxpy>=1.1.19 in d:\0awork\envs\finrl311\lib\site-packages (from PyPortfolioOpt) (1.6.5)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in d:\0awork\envs\finrl311\lib\site-packages (from PyPortfolioOpt) (2.0.14)
# Requirement already satisfied: numpy>=1.26.0 in d:\0awork\envs\finrl311\lib\site-packages (from PyPortfolioOpt) (2.2.6)
# Requirement already satisfied: pandas>=0.19 in d:\0awork\envs\finrl311\lib\site-packages (from PyPortfolioOpt) (2.2.3)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in d:\0awork\envs\finrl311\lib\site-packages (from PyPortfolioOpt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in d:\0awork\envs\finrl311\lib\site-packages (from PyPortfolioOpt) (1.15.3)
# Requirement already satisfied: tenacity>=6.2.0 in d:\0awork\envs\finrl311\lib\site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (9.1.2)
# Requirement already satisfied: packaging in d:\0awork\envs\finrl311\lib\site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (24.2)
# Requirement already satisfied: osqp>=0.6.2 in d:\0awork\envs\finrl311\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in d:\0awork\envs\finrl311\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.11.0)
# Requirement already satisfied: scs>=3.2.4.post1 in d:\0awork\envs\finrl311\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.7.post2)
# Requirement already satisfied: cffi in d:\0awork\envs\finrl311\lib\site-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (1.17.1)
# Requirement already satisfied: jinja2 in d:\0awork\envs\finrl311\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.1.6)
# Requirement already satisfied: setuptools in d:\0awork\envs\finrl311\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (78.1.1)
# Requirement already satisfied: joblib in d:\0awork\envs\finrl311\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\0awork\envs\finrl311\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\0awork\envs\finrl311\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\0awork\envs\finrl311\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\0awork\envs\finrl311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.17.0)
# Requirement already satisfied: pycparser in d:\0awork\envs\finrl311\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\0awork\envs\finrl311\lib\site-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#         date      close       high        low       open     volume   tic  \
# 0 2008-12-31   2.565124   2.636953   2.564824   2.583758  607541200  AAPL
# 1 2008-12-31  39.934002  40.259007  39.456869  39.491444    6287200  AMGN
# 2 2008-12-31  14.326870  14.481338  13.832574  13.878914    9625600   AXP
# 3 2008-12-31  32.005890  32.290921  31.128298  31.195806    5443100    BA
# 4 2008-12-31  28.895695  29.173849  28.268232  28.268232    6277400   CAT
#
#    day      macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0    2 -0.082003   3.071161   2.436449  42.254748  -80.847374  16.129765
# 1    2  0.149619  40.761999  38.992587  51.060624   51.895824  10.431979
# 2    2 -0.919292  18.322187  12.440030  42.554847  -74.811618  25.744929
# 3    2 -0.279800  32.174386  28.867831  47.440240  157.922155   5.392061
# 4    2  0.639822  29.617321  24.842690  51.205311   98.904648  26.480641
#
#    close_30_sma  close_60_sma  \
# 0      2.729571      2.840867
# 1     39.188100     38.754531
# 2     15.469928     17.309637
# 3     30.327214     32.389915
# 4     26.046880     25.787324
#
#                                             cov_list  \
# 0  [[0.0013489675018974383, 0.0004284139260326614...
# 1  [[0.0013489675018974383, 0.0004284139260326614...
# 2  [[0.0013489675018974383, 0.0004284139260326614...
# 3  [[0.0013489675018974383, 0.0004284139260326614...
# 4  [[0.0013489675018974383, 0.0004284139260326614...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()

    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)

portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()
# Out:
#              account_value
# 2020-07-01         1000000
# 2020-07-02  1005253.920151
# 2020-07-06  1014938.501816
# 2020-07-07   1014208.56556
# 2020-07-08   1012633.81571

# %%
a2c_cumpod =(df_daily_return.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1
# Out:
# C:\Users\Aaron_2\AppData\Local\Temp\tmpnp0infbp\ipykernel_31264\3389022641.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly
# Out:
# Looking in indexes: https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple
# Requirement already satisfied: plotly in d:\0awork\envs\finrl311\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\0awork\envs\finrl311\lib\site-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in d:\0awork\envs\finrl311\lib\site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)



fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2

    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date',
       'tick0': time_ind[0],
        'tickmode': 'linear',
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
